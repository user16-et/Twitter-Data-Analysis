# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %pwd

# %%
# %cd /content/drive/MyDrive/

# %%
# %cd Colab Notebooks/10xac

# %%
# %ls

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Economic_Twitter_Data.csv")

# %%
df.head(5)
# Out:
#                        created_at               source  \
# 0  Fri Apr 22 22:20:18 +0000 2022  Twitter for Android
# 1  Fri Apr 22 22:19:16 +0000 2022  Twitter for Android
# 2  Fri Apr 22 22:17:28 +0000 2022  Twitter for Android
# 3  Fri Apr 22 22:17:20 +0000 2022  Twitter for Android
# 4  Fri Apr 22 22:13:15 +0000 2022  Twitter for Android
#
#                                        original_text polarity  subjectivity  \
# 0  RT @nikitheblogger: Irre: Annalena Baerbock sa...      0.0           0.0
# 1  RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...      0.0           0.0
# 2  RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...      0.0           0.0
# 3  RT @WRi007: Die #Deutschen sind ein braves Vol...      0.0           0.0
# 4  RT @RolandTichy: Baerbock verkündet mal so neb...      0.0           0.0
#
#   lang favorite_count  retweet_count original_author followers_count  \
# 0   de              0          355.0    McMc74078966               3
# 1   de              0          505.0    McMc74078966               3
# 2   de              0            4.0    McMc74078966               3
# 3   de              0          332.0    McMc74078966               3
# 4   de              0          386.0    McMc74078966               3
#
#   friends_count possibly_sensitive  \
# 0            12                NaN
# 1            12                NaN
# 2            12                NaN
# 3            12                NaN
# 4            12                NaN
#
#                                             hashtags  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  ['Deutschen', 'Spritpreisen', 'inflation', 'Ab...
# 4                                                 []
#
#               user_mentions place
# 0        ['nikitheblogger']   NaN
# 1              ['sagt_mit']   NaN
# 2  ['Kryptonoun', 'WRi007']   NaN
# 3                ['WRi007']   NaN
# 4           ['RolandTichy']   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24636 entries, 0 to 24636
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   created_at          24636 non-null  object
#  1   source              24633 non-null  object
#  2   original_text       24633 non-null  object
#  3   polarity            24625 non-null  object
#  4   subjectivity        24625 non-null  float64
#  5   lang                24625 non-null  object
#  6   favorite_count      24625 non-null  object
#  7   retweet_count       24625 non-null  float64
#  8   original_author     24625 non-null  object
#  9   followers_count     24618 non-null  object
#  10  friends_count       24625 non-null  object
#  11  possibly_sensitive  9982 non-null   object
#  12  hashtags            24624 non-null  object
#  13  user_mentions       24617 non-null  object
#  14  place               15724 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#        subjectivity  retweet_count
# count  24625.000000   24625.000000
# mean       0.218766     539.573320
# std        0.302759    6045.401044
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        0.000000       2.000000
# 75%        0.446296      39.000000
# max        1.000000  434379.000000

# %%
df.isnull().sum()
# Out:
# created_at                0
# source                    3
# original_text             3
# polarity                 11
# subjectivity             11
# lang                     11
# favorite_count           11
# retweet_count            11
# original_author          11
# followers_count          18
# friends_count            11
# possibly_sensitive    14654
# hashtags                 12
# user_mentions            19
# place                  8912
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 23698

# %%
df.isna()
# Out:
#        created_at  source  original_text  polarity  subjectivity   lang  \
# 0           False   False          False     False         False  False
# 1           False   False          False     False         False  False
# 2           False   False          False     False         False  False
# 3           False   False          False     False         False  False
# 4           False   False          False     False         False  False
# ...           ...     ...            ...       ...           ...    ...
# 24632       False   False          False     False         False  False
# 24633       False   False          False     False         False  False
# 24634       False   False          False     False         False  False
# 24635       False   False          False     False         False  False
# 24636       False   False          False     False         False  False
#
#        favorite_count  retweet_count  original_author  followers_count  \
# 0               False          False            False            False
# 1               False          False            False            False
# 2               False          False            False            False
# 3               False          False            False            False
# 4               False          False            False            False
# ...               ...            ...              ...              ...
# 24632           False          False            False            False
# 24633           False          False            False            False
# 24634           False          False            False            False
# 24635           False          False            False            False
# 24636           False          False            False            False
#
#        friends_count  possibly_sensitive  hashtags  user_mentions  place
# 0              False                True     False          False   True
# 1              False                True     False          False   True
# 2              False                True     False          False   True
# 3              False                True     False          False   True
# 4              False                True     False          False   True
# ...              ...                 ...       ...            ...    ...
# 24632          False                True     False          False   True
# 24633          False                True     False          False   True
# 24634          False                True     False          False   True
# 24635          False                True     False          False   True
# 24636          False                True     False          False   True
#
# [24637 rows x 15 columns]

# %%
df.shape
# Out:
# (24637, 15)

# %%
 df.drop_duplicates(inplace=True)

# %%
 df.drop(["retweet_count"], axis=1)
# Out:
#                            created_at               source  \
# 0      Fri Apr 22 22:20:18 +0000 2022  Twitter for Android
# 1      Fri Apr 22 22:19:16 +0000 2022  Twitter for Android
# 2      Fri Apr 22 22:17:28 +0000 2022  Twitter for Android
# 3      Fri Apr 22 22:17:20 +0000 2022  Twitter for Android
# 4      Fri Apr 22 22:13:15 +0000 2022  Twitter for Android
# ...                               ...                  ...
# 24632  Fri Apr 22 14:44:56 +0000 2022   Twitter for iPhone
# 24633  Fri Apr 22 14:44:44 +0000 2022   Twitter for iPhone
# 24634  Fri Apr 22 14:44:35 +0000 2022   Twitter for iPhone
# 24635  Fri Apr 22 14:44:08 +0000 2022   Twitter for iPhone
# 24636  Fri Apr 22 14:43:01 +0000 2022   Twitter for iPhone
#
#                                            original_text polarity  \
# 0      RT @nikitheblogger: Irre: Annalena Baerbock sa...      0.0
# 1      RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...      0.0
# 2      RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...      0.0
# 3      RT @WRi007: Die #Deutschen sind ein braves Vol...      0.0
# 4      RT @RolandTichy: Baerbock verkündet mal so neb...      0.0
# ...                                                  ...      ...
# 24632  RT @waglenikhil: आपल्या घरातल्या कोणत्याही कार...      0.0
# 24633  RT @yadavtejashwi: चौहरमल नगर, फुलवारी शरीफ मे...      0.0
# 24634  RT @Parthtiwari25: Gujarat Congress MLA arrest...      0.0
# 24635  RT @news24tvchannel: CM नीतीश कुमार ने तेजस्वी...      0.0
# 24636  RT @suvegrathi: भगवान और खुदा आपस में बात कर र...      0.0
#
#        subjectivity lang favorite_count original_author followers_count  \
# 0               0.0   de              0    McMc74078966               3
# 1               0.0   de              0    McMc74078966               3
# 2               0.0   de              0    McMc74078966               3
# 3               0.0   de              0    McMc74078966               3
# 4               0.0   de              0    McMc74078966               3
# ...             ...  ...            ...             ...             ...
# 24632           0.0   mr              0   kitukalesatya             706
# 24633           0.0   hi              0   kitukalesatya             706
# 24634           0.0   en              0   kitukalesatya             706
# 24635           0.0   hi              0   kitukalesatya             706
# 24636           0.0   hi              0   kitukalesatya             706
#
#       friends_count possibly_sensitive  \
# 0                12                NaN
# 1                12                NaN
# 2                12                NaN
# 3                12                NaN
# 4                12                NaN
# ...             ...                ...
# 24632           643                NaN
# 24633           643                NaN
# 24634           643                NaN
# 24635           643                NaN
# 24636           643                NaN
#
#                                                 hashtags  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3      ['Deutschen', 'Spritpreisen', 'inflation', 'Ab...
# 4                                                     []
# ...                                                  ...
# 24632                                                 []
# 24633                                                 []
# 24634                                                 []
# 24635                                                 []
# 24636                                                 []
#
#                          user_mentions place
# 0                   ['nikitheblogger']   NaN
# 1                         ['sagt_mit']   NaN
# 2             ['Kryptonoun', 'WRi007']   NaN
# 3                           ['WRi007']   NaN
# 4                      ['RolandTichy']   NaN
# ...                                ...   ...
# 24632                  ['waglenikhil']   NaN
# 24633                ['yadavtejashwi']   NaN
# 24634                ['Parthtiwari25']   NaN
# 24635              ['news24tvchannel']   NaN
# 24636  ['suvegrathi', 'BajpayeeManoj']   NaN
#
# [24636 rows x 14 columns]

# %%
df.dropna(axis=0,inplace=False)
#df = df[df['lang'].str.contains("en")]
#df['created_at'] = pd.to_datetime(df['created_at'])
# Out:
#                            created_at               source  \
# 88     Fri Apr 22 22:32:03 +0000 2022   Twitter for iPhone
# 89     Fri Apr 22 22:16:55 +0000 2022   Twitter for iPhone
# 90     Fri Apr 22 07:15:28 +0000 2022   Twitter for iPhone
# 91     Fri Apr 22 07:11:18 +0000 2022   Twitter for iPhone
# 92     Fri Apr 22 07:08:54 +0000 2022   Twitter for iPhone
# ...                               ...                  ...
# 24522  Fri Apr 22 11:19:46 +0000 2022  Twitter for Android
# 24524  Fri Apr 22 11:19:38 +0000 2022  Twitter for Android
# 24528  Fri Apr 22 11:19:19 +0000 2022  Twitter for Android
# 24529  Fri Apr 22 11:19:17 +0000 2022  Twitter for Android
# 24535  Fri Apr 22 09:37:27 +0000 2022  Twitter for Android
#
#                                            original_text  \
# 88     MICKEY’S BAD MOVE: @GovRonDeSantis has now sig...
# 89     ELECTIONS HAVE CONSEQUENCES: Biden’s historic ...
# 90     COINCIDENCE? 18 U.S. food processing facilitie...
# 91     FOOD PROCESSING PLANTS BEING DESTROYED: “A Sma...
# 92             RT @JackPosobiec: https://t.co/M5xGy6Y2BQ
# ...                                                  ...
# 24522    RT @IYC: टूटता है भारत! https://t.co/4NplYUammS
# 24524  RT @INC_Television: पटना:सुशासन राज की पोल खोल...
# 24528  RT @WithCongress: भाजपा राज में काले धंधे ! ht...
# 24529  RT @INCMP: रतलाम जनसभा की झलकियाँ। https://t.c...
# 24535  Thank you @BajpayeeManoj ji for this beautiful...
#
#                    polarity  subjectivity lang favorite_count  retweet_count  \
# 88     -0.03749999999999987      0.533333   en              1            0.0
# 89     -0.06666666666666667      0.033333   en              1            0.0
# 90     -0.07777777777777779      0.177778   en              4            1.0
# 91     -0.09999999999999999      0.450000   en              3            2.0
# 92                      0.0      0.000000  und              0         3604.0
# ...                     ...           ...  ...            ...            ...
# 24522                   0.0      0.000000   hi              0          240.0
# 24524                   0.0      0.000000   hi              0          111.0
# 24528                   0.0      0.000000   hi              0           20.0
# 24529                   0.0      0.000000   hi              0          266.0
# 24535                  0.85      1.000000   en              7            6.0
#
#        original_author followers_count friends_count possibly_sensitive  \
# 88      MercuryReports            9254          9422              False
# 89      MercuryReports            9254          9422              False
# 90      MercuryReports            9254          9422              False
# 91      MercuryReports            9254          9422              False
# 92      MercuryReports            9254          9422              False
# ...                ...             ...           ...                ...
# 24522  ibrahimpatel007            4684          1225              False
# 24524  ibrahimpatel007            4684          1225              False
# 24528  ibrahimpatel007            4684          1225              False
# 24529  ibrahimpatel007            4684          1225              False
# 24535  ibrahimpatel007            4684          1225               True
#
#       hashtags       user_mentions             place
# 88          []  ['GovRonDeSantis']  All Over America
# 89          []                  []  All Over America
# 90          []                  []  All Over America
# 91          []                  []  All Over America
# 92          []    ['JackPosobiec']  All Over America
# ...        ...                 ...               ...
# 24522       []             ['IYC']  Hyderabad, India
# 24524       []  ['INC_Television']  Hyderabad, India
# 24528       []    ['WithCongress']  Hyderabad, India
# 24529       []           ['INCMP']  Hyderabad, India
# 24535       []   ['BajpayeeManoj']  Hyderabad, India
#
# [6786 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24636 entries, 0 to 24636
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   created_at          24636 non-null  object
#  1   source              24633 non-null  object
#  2   original_text       24633 non-null  object
#  3   polarity            24625 non-null  object
#  4   subjectivity        24625 non-null  float64
#  5   lang                24625 non-null  object
#  6   favorite_count      24625 non-null  object
#  7   retweet_count       24625 non-null  float64
#  8   original_author     24625 non-null  object
#  9   followers_count     24618 non-null  object
#  10  friends_count       24625 non-null  object
#  11  possibly_sensitive  9982 non-null   object
#  12  hashtags            24624 non-null  object
#  13  user_mentions       24617 non-null  object
#  14  place               15724 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 3.0+ MB

# %%
df["polarity"] = pd.to_numeric(df["polarity"])
df["subjectivity"] = pd.to_numeric(df["subjectivity"])
df["retweet_count"] = pd.to_numeric(df["retweet_count"])
df["favorite_count"] = pd.to_numeric(df["favorite_count"])
df["friends_count "] = pd.to_numeric(df["friends_count"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24574 entries, 0 to 24624
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   created_at       24574 non-null  datetime64[ns, UTC]
#  1   source           24574 non-null  object
#  2   original_text    24574 non-null  object
#  3   polarity         24574 non-null  float64
#  4   subjectivity     24574 non-null  float64
#  5   lang             24574 non-null  object
#  6   favorite_count   24574 non-null  int64
#  7   retweet_count    24574 non-null  int64
#  8   original_author  24574 non-null  object
#  9   followers_count  24574 non-null  int64
#  10  friends_count    24574 non-null  int64
#  11  sensetivity      9964 non-null   object
#  12  hashtags         24574 non-null  object
#  13  user_mentions    18063 non-null  object
#  14  place            15700 non-null  object
#  15  friends_count    24574 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(2), int64(5), object(8)
# memory usage: 3.2+ MB
