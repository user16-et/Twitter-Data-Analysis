# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %pwd

# %%
# %cd /content/drive/MyDrive/

# %%
# %cd Colab Notebooks/10xac

# %%
# %ls

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cleaned_tweets.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0                 created_at              source  \
# 0           0  2022-04-22 22:32:03+00:00  Twitter for iPhone
# 1           1  2022-04-22 22:16:55+00:00  Twitter for iPhone
# 2           2  2022-04-22 07:15:28+00:00  Twitter for iPhone
# 3           3  2022-04-22 07:11:18+00:00  Twitter for iPhone
# 4           4  2022-04-21 22:22:02+00:00  Twitter for iPhone
#
#                                        original_text  polarity  subjectivity  \
# 0  MICKEY’S BAD MOVE: @GovRonDeSantis has now sig... -0.037500      0.533333
# 1  ELECTIONS HAVE CONSEQUENCES: Biden’s historic ... -0.066667      0.033333
# 2  COINCIDENCE? 18 U.S. food processing facilitie... -0.077778      0.177778
# 3  FOOD PROCESSING PLANTS BEING DESTROYED: “A Sma... -0.100000      0.450000
# 4  DISGUSTING HUMAN BEING: What one person calls ... -0.500000      0.550000
#
#   lang  favorite_count  retweet_count original_author  followers_count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4307 entries, 0 to 4306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4307 non-null   int64
#  1   created_at          4307 non-null   object
#  2   source              4307 non-null   object
#  3   original_text       4307 non-null   object
#  4   polarity            4307 non-null   float64
#  5   subjectivity        4307 non-null   float64
#  6   lang                4307 non-null   object
#  7   favorite_count      4307 non-null   int64
#  8   retweet_count       4307 non-null   float64
#  9   original_author     4307 non-null   object
#  10  followers_count     4307 non-null   int64
#  11  friends_count       4307 non-null   int64
#  12  possibly_sensitive  4307 non-null   bool
#  13  hashtags            4307 non-null   object
#  14  user_mentions       4307 non-null   object
# ...

# %%
df.drop("Unnamed: 0", axis=1)
# Out:
#                      created_at                          source  \
# 0     2022-04-22 22:32:03+00:00              Twitter for iPhone
# 1     2022-04-22 22:16:55+00:00              Twitter for iPhone
# 2     2022-04-22 07:15:28+00:00              Twitter for iPhone
# 3     2022-04-22 07:11:18+00:00              Twitter for iPhone
# 4     2022-04-21 22:22:02+00:00              Twitter for iPhone
# ...                         ...                             ...
# 4302  2022-04-22 14:00:54+00:00  Twitter Media Studio - LiveCut
# 4303  2022-04-22 13:52:56+00:00             Twitter for Android
# 4304  2022-04-22 13:38:49+00:00             Twitter for Android
# 4305  2022-04-22 13:38:43+00:00             Twitter for Android
# 4306  2022-04-22 09:37:27+00:00             Twitter for Android
#
#                                           original_text  polarity  \
# 0     MICKEY’S BAD MOVE: @GovRonDeSantis has now sig... -0.037500
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# created_at            0
# source                0
# original_text         0
# polarity              0
# subjectivity          0
# lang                  0
# favorite_count        0
# retweet_count         0
# original_author       0
# followers_count       0
# friends_count         0
# possibly_sensitive    0
# hashtags              0
# user_mentions         0
# place                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (4307, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4307 entries, 0 to 4306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4307 non-null   int64
#  1   created_at          4307 non-null   object
#  2   source              4307 non-null   object
#  3   original_text       4307 non-null   object
#  4   polarity            4307 non-null   float64
#  5   subjectivity        4307 non-null   float64
#  6   lang                4307 non-null   object
#  7   favorite_count      4307 non-null   int64
#  8   retweet_count       4307 non-null   float64
#  9   original_author     4307 non-null   object
#  10  followers_count     4307 non-null   int64
#  11  friends_count       4307 non-null   int64
#  12  possibly_sensitive  4307 non-null   bool
#  13  hashtags            4307 non-null   object
#  14  user_mentions       4307 non-null   object
# ...

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4307 entries, 0 to 4306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4307 non-null   int64
#  1   created_at          4307 non-null   datetime64[ns, UTC]
#  2   source              4307 non-null   object
#  3   original_text       4307 non-null   object
#  4   polarity            4307 non-null   float64
#  5   subjectivity        4307 non-null   float64
#  6   lang                4307 non-null   object
#  7   favorite_count      4307 non-null   int64
#  8   retweet_count       4307 non-null   float64
#  9   original_author     4307 non-null   object
#  10  followers_count     4307 non-null   int64
#  11  friends_count       4307 non-null   int64
#  12  possibly_sensitive  4307 non-null   bool
#  13  hashtags            4307 non-null   object
#  14  user_mentions       4307 non-null   object
# ...

# %%
p_df=df.drop("Unnamed: 0", axis=1)

# %%
p_df.head(10)
# Out:
#                  created_at              source  \
# 0 2022-04-22 22:32:03+00:00  Twitter for iPhone
# 1 2022-04-22 22:16:55+00:00  Twitter for iPhone
# 2 2022-04-22 07:15:28+00:00  Twitter for iPhone
# 3 2022-04-22 07:11:18+00:00  Twitter for iPhone
# 4 2022-04-21 22:22:02+00:00  Twitter for iPhone
# 5 2022-04-21 22:07:20+00:00  Twitter for iPhone
# 6 2022-04-21 10:16:46+00:00  Twitter for iPhone
# 7 2022-04-21 09:52:34+00:00  Twitter for iPhone
# 8 2022-04-21 09:40:32+00:00  Twitter for iPhone
# 9 2022-04-19 10:37:26+00:00  Twitter for iPhone
#
#                                        original_text  polarity  subjectivity  \
# 0  MICKEY’S BAD MOVE: @GovRonDeSantis has now sig... -0.037500      0.533333
# 1  ELECTIONS HAVE CONSEQUENCES: Biden’s historic ... -0.066667      0.033333
# 2  COINCIDENCE? 18 U.S. food processing facilitie... -0.077778      0.177778
# 3  FOOD PROCESSING PLANTS BEING DESTROYED: “A Sma... -0.100000      0.450000
# ...

# %%
p_df.columns
# Out:
# Index(['created_at', 'source', 'original_text', 'polarity', 'subjectivity',
#        'lang', 'favorite_count', 'retweet_count', 'original_author',
#        'followers_count', 'friends_count', 'possibly_sensitive', 'hashtags',
#        'user_mentions', 'place'],
#       dtype='object')

# %%
p_df.shape
# Out:
# (4307, 15)

# %% [markdown]
# next select only relevant columns for sentmental analysis

# %%
dataset=p_df[['original_text', 'polarity', 'subjectivity']]

# %%
dataset.head(10)
# Out:
#                                        original_text  polarity  subjectivity
# 0  MICKEY’S BAD MOVE: @GovRonDeSantis has now sig... -0.037500      0.533333
# 1  ELECTIONS HAVE CONSEQUENCES: Biden’s historic ... -0.066667      0.033333
# 2  COINCIDENCE? 18 U.S. food processing facilitie... -0.077778      0.177778
# 3  FOOD PROCESSING PLANTS BEING DESTROYED: “A Sma... -0.100000      0.450000
# 4  DISGUSTING HUMAN BEING: What one person calls ... -0.500000      0.550000
# 5  MASS EXPERIMENT ON HUMANITY: "Despite the fact...  0.000000      0.300000
# 6  DISNEY WILL NOT RUN FLORIDA: The Florida Senat...  0.357143      0.571429
# 7  AMERICA’S SPACE CADET: Russia's Putin and Chin... -0.600000      1.000000
# 8  AMERICA’S MOST INCOMPETENT: Biden surpasses Ji...  0.060000      0.346667
# 9  MAYOR OF CRAZY TOWN: Why is the Easter Bunny d... -0.300000      0.950000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset["original_text"]=dataset["original_text"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
dataset.head()
# Out:
#                                        original_text  polarity  subjectivity
# 0  mickey’s bad move: @govrondesantis has now sig... -0.037500      0.533333
# 1  elections have consequences: biden’s historic ... -0.066667      0.033333
# 2  coincidence? 18 u.s. food processing facilitie... -0.077778      0.177778
# 3  food processing plants being destroyed: “a sma... -0.100000      0.450000
# 4  disgusting human being: what one person calls ... -0.500000      0.550000

# %%
dataset["original_text"]=dataset["original_text"].str.replace('[^\w\s]','')

# %%
dataset.head()
# Out:
#                                        original_text  polarity  subjectivity
# 0  mickeys bad move govrondesantis has now signed... -0.037500      0.533333
# 1  elections have consequences bidens historic mi... -0.066667      0.033333
# 2  coincidence 18 us food processing facilities b... -0.077778      0.177778
# 3  food processing plants being destroyed a small... -0.100000      0.450000
# 4  disgusting human being what one person calls h... -0.500000      0.550000

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  
                           u"\U0001F300-\U0001F5FF"  
                           u"\U0001F680-\U0001F6FF"  
                           u"\U0001F1E0-\U0001F1FF"  
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
dataset["original_text"]=dataset["original_text"].apply(lambda x: remove_emoji(x))

# %%
dataset.head()
# Out:
#                                        original_text  polarity  subjectivity
# 0  mickeys bad move govrondesantis has now signed... -0.037500      0.533333
# 1  elections have consequences bidens historic mi... -0.066667      0.033333
# 2  coincidence 18 us food processing facilities b... -0.077778      0.177778
# 3  food processing plants being destroyed a small... -0.100000      0.450000
# 4  disgusting human being what one person calls h... -0.500000      0.550000

# %%
#from nltk.corpus import stopwords
#stop = stopwords.words('english')
#dataset["original_text"]=dataset["original_text"].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\3724036612.py in <module>
# ----> 1 stop = stopwords.words('english')
#       2 dataset["original_text"]=dataset["original_text"].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
#
# NameError: name 'stopwords' is not defined
